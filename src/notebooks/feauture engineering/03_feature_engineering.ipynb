# %% [markdown]
# # Feature engineering 1 - parte A
#
# Colunas PESSOA_PIPEDRIVE_contract_start_date até FUNIL_ASSINATURA_PIPEDRIVE_id_stage

# %%
import pandas as pd

data = pd.read_csv("../data/data-preprocessed.csv")

# %% [markdown]
# ## PESSOA_PIPEDRIVE_contract_start_date
#
# Coluna já foi utilizada para a confecção de outras, pode ser dropada.

# %%
data['PESSOA_PIPEDRIVE_contract_start_date']
# Out:
# 0      2021-01-27
# 1      2022-06-21
# 2      2021-07-05
# 3      2021-06-28
# 4      2021-06-28
#           ...
# 967    2023-11-06
# 968    2023-11-07
# 969    2023-11-07
# 970    2023-11-07
# 971    2023-11-08
# Name: PESSOA_PIPEDRIVE_contract_start_date, Length: 972, dtype: object

# %%
data.drop(columns=['PESSOA_PIPEDRIVE_contract_start_date'], inplace=True)

# %% [markdown]
# ## PESSOA_PIPEDRIVE_contract_end_date
#
# Coluna já foi utilizada para a confecção de outras, pode ser dropada.

# %%
data['PESSOA_PIPEDRIVE_contract_end_date']
# Out:
# 0      2023-08-26
# 1      2023-09-20
# 2      2021-10-01
# 3      2023-09-16
# 4      2022-02-07
#           ...
# 967           NaN
# 968           NaN
# 969           NaN
# 970           NaN
# 971           NaN
# Name: PESSOA_PIPEDRIVE_contract_end_date, Length: 972, dtype: object

# %%
data.drop(columns=['PESSOA_PIPEDRIVE_contract_end_date'], inplace=True)

# %% [markdown]
# ## PESSOA_PIPEDRIVE_Canal de Preferência
#
# Aplica one hot encoding na coluna

# %%
lost_reason_dummies = pd.get_dummies(data['PESSOA_PIPEDRIVE_Canal de Preferência'], prefix='canal_de_preferencia')
data = pd.concat([data, lost_reason_dummies], axis=1)

data
# Out:
#      PESSOA_PIPEDRIVE_id_person  PESSOA_PIPEDRIVE_id_gender  \
# 0                           483                          64
# 1                           860                          63
# 2                           961                          63
# 3                           972                          63
# 4                           973                          64
# ..                          ...                         ...
# 967                        5944                          64
# 968                        5948                          64
# 969                        5949                          64
# 970                        5954                          63
# 971                        5956                          63
#
#      PESSOA_PIPEDRIVE_id_marrital_status PESSOA_PIPEDRIVE_state  \
# 0                                     80           Minas Gerais
# 1                                     80                 Paraná
# 2                                     80         Santa Catarina
# 3                                     82           Minas Gerais
# 4                                     80           Minas Gerais
# ..                                   ...                    ...
# 967                                   80                Paraíba
# 968                                   80                  Bahia
# 969                                   80              São Paulo
# 970                                   82              São Paulo
# 971                                   82         Rio de Janeiro
#
#     PESSOA_PIPEDRIVE_city PESSOA_PIPEDRIVE_postal_code  \
# 0            Juiz de Fora                    36021-600
# 1                Londrina                    86020-410
# 2           Florianópolis                    88080-080
# 3              Uberlândia                    38400-438
# 4              Uberlândia                    38405-364
# ..                    ...                          ...
# 967           João Pessoa                    58052-310
# 968              Salvador                    41830-120
# 969             São Paulo                    05014-001
# 970             São Paulo                    04513-100
# 971        Rio de Janeiro                    22280-010
#
#      PESSOA_PIPEDRIVE_Canal de Preferência  PESSOA_PIPEDRIVE_notes_count  \
# 0                                        0                             3
# 1                                      239                             3
# 2                                        0                             1
# 3                                        0                             2
# 4                                        0                             1
# ..                                     ...                           ...
# 967                                    239                             0
# 968                                      0                             0
# 969                                    239                             0
# 970                                    239                             0
# 971                                      0                             0
#
#      PESSOA_PIPEDRIVE_done_activities_count  \
# 0                                        10
# 1                                        16
# 2                                         1
# 3                                        14
# 4                                         6
# ..                                      ...
# 967                                       0
# 968                                       0
# 969                                       0
# 970                                       0
# 971                                       0
#
#      FUNIL_ASSINATURA_PIPEDRIVE_id_stage  ...  \
# 0                                     64  ...
# 1                                     64  ...
# 2                                     65  ...
# 3                                     65  ...
# 4                                     65  ...
# ..                                   ...  ...
# 967                                   65  ...
# 968                                   65  ...
# 969                                   65  ...
# 970                                   64  ...
# 971                                   65  ...
#
#      COMUNICARE_Problemas Abertos Bool  \
# 0                                    0
# 1                                    1
# 2                                    0
# 3                                    1
# 4                                    0
# ..                                 ...
# 967                                  0
# 968                                  1
# 969                                  0
# 970                                  0
# 971                                  0
#
#     TWILIO_Data Última Mensagens Inbound Recente last_stage_concluded  \
# 0                                              0         Questionário
# 1                                              1         Questionário
# 2                                              0          Boas-vindas
# 3                                              1         Questionário
# 4                                              0         Questionário
# ..                                           ...                  ...
# 967                                            0          Boas-vindas
# 968                                            0     Primeira reunião
# 969                                            0          Boas-vindas
# 970                                            0          Boas-vindas
# 971                                            0          Boas-vindas
#
#             process_time TWILIO_Data Última Mensagens Outbound Recente  \
# 0    2022-04-19 15:19:40                                             1
# 1    2022-06-27 15:03:30                                             1
# 2    2021-10-04 12:25:41                                             0
# 3    2022-05-05 13:14:01                                             1
# 4    2022-02-07 03:00:00                                             0
# ..                   ...                                           ...
# 967            Em aberto                                             0
# 968            Em aberto                                             0
# 969            Em aberto                                             0
# 970            Em aberto                                             0
# 971            Em aberto                                             0
#
#     TWILIO_Data Última Ligações Outbound Recente canal_de_preferencia_0  \
# 0                                              1                      1
# 1                                              0                      0
# 2                                              0                      1
# 3                                              0                      1
# 4                                              0                      1
# ..                                           ...                    ...
# 967                                            0                      0
# 968                                            0                      1
# 969                                            0                      0
# 970                                            0                      0
# 971                                            0                      1
#
#     canal_de_preferencia_238  canal_de_preferencia_239  \
# 0                          0                         0
# 1                          0                         1
# 2                          0                         0
# 3                          0                         0
# 4                          0                         0
# ..                       ...                       ...
# 967                        0                         1
# 968                        0                         0
# 969                        0                         1
# 970                        0                         1
# 971                        0                         0
#
#      canal_de_preferencia_360
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# ..                        ...
# 967                         0
# 968                         0
# 969                         0
# 970                         0
# 971                         0
#
# [972 rows x 52 columns]

# %% [markdown]
# ## PESSOA_PIPEDRIVE_notes_count
#
# Tudo certo por aqui, nada a acrescentar

# %%
data['PESSOA_PIPEDRIVE_notes_count']
# Out:
# 0      3.0
# 1      3.0
# 2      1.0
# 3      2.0
# 4      1.0
#       ...
# 967    0.0
# 968    0.0
# 969    0.0
# 970    0.0
# 971    0.0
# Name: PESSOA_PIPEDRIVE_notes_count, Length: 972, dtype: float64

# %% [markdown]
# ## PESSOA_PIPEDRIVE_done_activities_count
#
# Tudo certo por aqui, nada a acrescentar

# %%
data['PESSOA_PIPEDRIVE_notes_count']
# Out:
# 0      3.0
# 1      3.0
# 2      1.0
# 3      2.0
# 4      1.0
#       ...
# 967    0.0
# 968    0.0
# 969    0.0
# 970    0.0
# 971    0.0
# Name: PESSOA_PIPEDRIVE_notes_count, Length: 972, dtype: float64

# %% [markdown]
# ## FUNIL_ASSINATURA_PIPEDRIVE_id_stage
#
# Tudo certo por aqui, nada a acrescentar

# %%
data['FUNIL_ASSINATURA_PIPEDRIVE_id_stage']
# Out:
# 0      64.0
# 1      64.0
# 2      65.0
# 3      65.0
# 4      65.0
#        ...
# 967    65.0
# 968    65.0
# 969    65.0
# 970    64.0
# 971    65.0
# Name: FUNIL_ASSINATURA_PIPEDRIVE_id_stage, Length: 972, dtype: float64
