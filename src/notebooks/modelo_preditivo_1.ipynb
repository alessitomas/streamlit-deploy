# %% [markdown]
# ## Modelo Preditivo

# %% [markdown]
# PENDENTE: FEATURE ENGINEERING
#
# 52/4 = 13
#
# 1: PESSOA_PIPEDRIVE_id_person até FUNIL_ASSINATURA_PIPEDRIVE_id_org
# 2: FUNIL_ASSINATURA_PIPEDRIVE_status até ATENDIMENTOS_AGENDA_Datas Atendimento Médico - Júlia
# 3: ATENDIMENTOS_AGENDA_Qde Atendimentos Acolhimento até PESSOA_PIPEDRIVE_Tem_Canal_de_Preferência
# 4: PESSOA_PIPEDRIVE_has_notes até TWILIO_Data Última Ligações Outbound Recente

# %% [markdown]
# 1. Geração de dataframe com dados pré-processados

# %%
import pandas as pd

data = pd.read_csv("../scripts/data-engineering.csv")
data.head()
# Out:
#   PESSOA_PIPEDRIVE_contract_start_date PESSOA_PIPEDRIVE_contract_end_date  \
# 0                           2021-01-27                         2023-08-26
# 1                           2021-01-27                         2023-08-26
# 2                           2021-08-16                         2022-08-16
# 3                           2021-08-12                         2022-09-11
# 4                           2021-08-18                         2022-10-11
#
#    PESSOA_PIPEDRIVE_Canal de Preferência  PESSOA_PIPEDRIVE_notes_count  \
# 0                                      0                             3
# 1                                      0                             3
# 2                                      0                             0
# 3                                      0                             1
# 4                                      0                             0
#
#    PESSOA_PIPEDRIVE_done_activities_count  \
# 0                                      10
# 1                                      10
# 2                                       9
# 3                                      14
# 4                                      11
#
#    FUNIL_ASSINATURA_PIPEDRIVE_id_stage  FUNIL_ASSINATURA_PIPEDRIVE_id_org  \
# 0                                   64                                NaN
# 1                                   64                                NaN
# 2                                   65                              382.0
# 3                                   65                              448.0
# 4                                   65                              448.0
#
#   FUNIL_ASSINATURA_PIPEDRIVE_status  \
# 0                              lost
# 1                              lost
# 2                              lost
# 3                              lost
# 4                              lost
#
#   FUNIL_ASSINATURA_PIPEDRIVE_start_of_service  \
# 0                                  2023-01-27
# 1                                  2023-01-27
# 2                                  2021-08-16
# 3                                  2021-08-12
# 4                                  2021-08-18
#
#   FUNIL_ASSINATURA_PIPEDRIVE_lost_time  ... Status_open Status_won  \
# 0                           2023-08-26  ...       False       True
# 1                           2023-08-26  ...       False       True
# 2                           2022-08-16  ...       False       True
# 3                           2022-09-11  ...       False      False
# 4                           2022-10-12  ...       False       True
#
#   lost_reason_Outro.1 lost_reason_[Associade] Cancelou assinatura  \
# 0                True                                       False
# 1                True                                       False
# 2                True                                       False
# 3               False                                       False
# 4                True                                       False
#
#    lost_reason_[Onboarding] Não retornou aos contatos de resgate  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    lost_reason_[Onboarding] Não tem interesse em seguir nas etapas do onboarding  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    stage_Boas-vindas  stage_Não iniciado stage_Primeira reunião  \
# 0              False               False                  False
# 1              False               False                  False
# 2              False               False                  False
# 3              False               False                  False
# 4              False               False                  False
#
#    stage_Questionário
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
#
# [5 rows x 103 columns]

# %%
data.shape[1]
# Out:
# 103

# %% [markdown]
# 2. Retenção das linhas com status = lost

# %%
for indice, linha in data.iterrows():
    if linha['FUNIL_ASSINATURA_PIPEDRIVE_status'] != 'lost':
        data.drop(indice, inplace=True)

print(data['FUNIL_ASSINATURA_PIPEDRIVE_status'])
# Out:
# 0      lost
# 1      lost
# 2      lost
# 3      lost
# 4      lost
#        ...
# 771    lost
# 772    lost
# 781    lost
# 795    lost
# 796    lost
# Name: FUNIL_ASSINATURA_PIPEDRIVE_status, Length: 292, dtype: object

# %% [markdown]
# 3. Separar x e y

# %%
X = data.drop(columns=['stay_time'], axis=1)
y = data['stay_time']

# %% [markdown]
# 4. Separar em grupos de treino e teste

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42,
)

# %% [markdown]
# 5. Testar modelos de regressão (support vector machine, random forest, logistic regressor)
