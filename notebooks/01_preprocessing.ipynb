# %% [markdown]
# # Preprocessing and cleaning of the data

# %%
import pandas as pd

# %%
data = pd.read_csv("../data/data.csv")

# %% [markdown]
# Raw dataset

# %%
data.head()
# Out:
#   PESSOA, PIPEDRIVE  Unnamed: 1 Unnamed: 2          Unnamed: 3  \
# 0         id_person   birthdate  id_gender  id_marrital_status
# 1               250  1971-04-01         64                  82
# 2               254         NaN        NaN                 NaN
# 3               314  1985-08-01        NaN                 NaN
# 4               315         NaN        NaN                 NaN
#
#        Unnamed: 4          Unnamed: 5   Unnamed: 6      Unnamed: 7  \
# 0           state                city  postal_code  id_health_plan
# 1       São Paulo           São Paulo    04534-020             417
# 2  North Carolina  Mecklenburg County        28203             NaN
# 3       São Paulo           São Paulo    05337-030             NaN
# 4             NaN                 NaN          NaN             NaN
#
#                  Unnamed: 8           Unnamed: 9  ...        Unnamed: 63  \
# 0  id_person_recommendation  contract_start_date  ...  Ligações Outbound
# 1                       NaN           2021-01-28  ...                  2
# 2                       NaN           2020-12-16  ...                NaN
# 3                       NaN           2021-01-21  ...                NaN
# 4                       NaN           2020-12-17  ...                NaN
#
#                      Unnamed: 64       COBRANÇA, VINDI  \
# 0  Data Última Ligações Outbound  Qde Total de Faturas
# 1            2022-04-25 19:18:52                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
#
#                            Unnamed: 66          Unnamed: 67  \
# 0  Qde Total de Tentativas de Cobrança  Método de Pagamento
# 1                                  NaN                  NaN
# 2                                  NaN                  NaN
# 3                                  NaN                  NaN
# 4                                  NaN                  NaN
#
#                   Unnamed: 68                                 Unnamed: 69  \
# 0  Valor Médio da Mensalidade  Qde Total de Faturas Pagas após Vencimento
# 1                         NaN                                         NaN
# 2                         NaN                                         NaN
# 3                         NaN                                         NaN
# 4                         NaN                                         NaN
#
#                          Unnamed: 70                Unnamed: 71  \
# 0  Qde Total de Faturas Inadimpletes  Valor Total Inadimplência
# 1                                NaN                        NaN
# 2                                NaN                        NaN
# 3                                NaN                        NaN
# 4                                NaN                        NaN
#
#                         Unnamed: 72
# 0  Qde Perfis de Pagamento Inativos
# 1                             FALSE
# 2                             FALSE
# 3                             FALSE
# 4                             FALSE
#
# [5 rows x 73 columns]

# %% [markdown]
# ## Manipulation of headers and columns

# %% [markdown]
# Merge Header with column names
#
#     - PESSOA, PIPEDRIVE coulmns [A,R]
#     - FUNIL ASSINATURA, PIPEDRIVE [S,X]
#     - FUNIL ONBOARDING, PIPEDRIVE [Y, AH]
#     - ATENDIMENTOS, AGENDA [AJ, AY]
#     - WHOQOL [AZ, BD]
#     - COMUNICARE [BE]
#     - TWILIO [BF, BM]
#     - COBRANÇA, VINDI [BN, BU]

# %%
def column_label_to_index(col_label):
    col_index = 0
    for c in col_label.upper():
        col_index = col_index * 26 + (ord(c) - ord('A') + 1)
    return col_index - 1


def add_prefix_to_first_row(dataframe, prefix, start_col_label, end_col_label):
    start_col = column_label_to_index(start_col_label)
    end_col = column_label_to_index(end_col_label)
    for col in range(start_col, end_col + 1):
        dataframe.iat[0, col] = prefix + dataframe.iat[0, col]

# %%
add_prefix_to_first_row(data, 'PESSOA_PIPEDRIVE_', 'A', 'R')
add_prefix_to_first_row(data, 'FUNIL_ASSINATURA_PIPEDRIVE_', 'S', 'X')
add_prefix_to_first_row(data, 'FUNI_ONBOARDING_PIPEDRIVE_', 'Y', 'AH')
add_prefix_to_first_row(data, 'ATENDIMENTOS_AGENDA_', 'AJ', 'AY')
add_prefix_to_first_row(data, 'WHOQOL_', 'AZ', 'BD')
add_prefix_to_first_row(data, 'COMUNICARE_', 'BE', 'BE')
add_prefix_to_first_row(data, 'TWILIO_', 'BF', 'BM')
add_prefix_to_first_row(data, 'COBRANÇA_VINDI_', 'BN', 'BU')

# %%
data.columns = data.iloc[0]
data = data.drop(data.index[0])

# %% [markdown]
# Final result

# %%
data.head()
# Out:
# 0 PESSOA_PIPEDRIVE_id_person PESSOA_PIPEDRIVE_birthdate  \
# 1                        250                 1971-04-01
# 2                        254                        NaN
# 3                        314                 1985-08-01
# 4                        315                        NaN
# 5                        317                 1986-10-14
#
# 0 PESSOA_PIPEDRIVE_id_gender PESSOA_PIPEDRIVE_id_marrital_status  \
# 1                         64                                  82
# 2                        NaN                                 NaN
# 3                        NaN                                 NaN
# 4                        NaN                                 NaN
# 5                        NaN                                 NaN
#
# 0 PESSOA_PIPEDRIVE_state PESSOA_PIPEDRIVE_city PESSOA_PIPEDRIVE_postal_code  \
# 1              São Paulo             São Paulo                    04534-020
# 2         North Carolina    Mecklenburg County                        28203
# 3              São Paulo             São Paulo                    05337-030
# 4                    NaN                   NaN                          NaN
# 5              São Paulo             São Paulo                    05421-050
#
# 0 PESSOA_PIPEDRIVE_id_health_plan PESSOA_PIPEDRIVE_id_person_recommendation  \
# 1                             417                                       NaN
# 2                             NaN                                       NaN
# 3                             NaN                                       NaN
# 4                             NaN                                       NaN
# 5                             NaN                                       NaN
#
# 0 PESSOA_PIPEDRIVE_contract_start_date  ... TWILIO_Ligações Outbound  \
# 1                           2021-01-28  ...                        2
# 2                           2020-12-16  ...                      NaN
# 3                           2021-01-21  ...                      NaN
# 4                           2020-12-17  ...                      NaN
# 5                           2021-01-18  ...                      NaN
#
# 0 TWILIO_Data Última Ligações Outbound COBRANÇA_VINDI_Qde Total de Faturas  \
# 1                  2022-04-25 19:18:52                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
# 5                                  NaN                                 NaN
#
# 0 COBRANÇA_VINDI_Qde Total de Tentativas de Cobrança  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 COBRANÇA_VINDI_Método de Pagamento  \
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
#
# 0 COBRANÇA_VINDI_Valor Médio da Mensalidade  \
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
#
# 0 COBRANÇA_VINDI_Qde Total de Faturas Pagas após Vencimento  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 COBRANÇA_VINDI_Qde Total de Faturas Inadimpletes  \
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
#
# 0 COBRANÇA_VINDI_Valor Total Inadimplência  \
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
#
# 0 COBRANÇA_VINDI_Qde Perfis de Pagamento Inativos
# 1                                           FALSE
# 2                                           FALSE
# 3                                           FALSE
# 4                                           FALSE
# 5                                           FALSE
#
# [5 rows x 73 columns]

# %% [markdown]
# ## Understanding the dataset

# %%
data.shape
# Out:
# (1202, 73)

# %%
data.describe()
# Out:
# 0      PESSOA_PIPEDRIVE_id_person PESSOA_PIPEDRIVE_birthdate  \
# count                        1202                       1191
# unique                       1202                       1100
# top                           250                 1995-01-16
# freq                            1                          8
#
# 0      PESSOA_PIPEDRIVE_id_gender PESSOA_PIPEDRIVE_id_marrital_status  \
# count                        1178                                1178
# unique                          5                                   4
# top                            64                                  80
# freq                          602                                 830
#
# 0      PESSOA_PIPEDRIVE_state PESSOA_PIPEDRIVE_city  \
# count                    1185                  1183
# unique                     24                   196
# top                 São Paulo             São Paulo
# freq                      570                   197
#
# 0      PESSOA_PIPEDRIVE_postal_code PESSOA_PIPEDRIVE_id_health_plan  \
# count                          1163                             524
# unique                          932                              47
# top                       69730-000                             412
# freq                             96                             281
#
# 0      PESSOA_PIPEDRIVE_id_person_recommendation  \
# count                                        110
# unique                                        81
# top                                         2379
# freq                                           9
#
# 0      PESSOA_PIPEDRIVE_contract_start_date  ... TWILIO_Ligações Outbound  \
# count                                  1202  ...                      579
# unique                                  422  ...                       16
# top                              2023-06-12  ...                        1
# freq                                     43  ...                      240
#
# 0      TWILIO_Data Última Ligações Outbound  \
# count                                   579
# unique                                  575
# top                     2022-12-22 19:46:59
# freq                                      3
#
# 0      COBRANÇA_VINDI_Qde Total de Faturas  \
# count                                  252
# unique                                  21
# top                                      3
# freq                                    35
#
# 0      COBRANÇA_VINDI_Qde Total de Tentativas de Cobrança  \
# count                                                 252
# unique                                                 36
# top                                                     1
# freq                                                   27
#
# 0      COBRANÇA_VINDI_Método de Pagamento  \
# count                                 252
# unique                                  4
# top                     Cartão de crédito
# freq                                  227
#
# 0      COBRANÇA_VINDI_Valor Médio da Mensalidade  \
# count                                        252
# unique                                        33
# top                                        88.00
# freq                                          99
#
# 0      COBRANÇA_VINDI_Qde Total de Faturas Pagas após Vencimento  \
# count                                                 252
# unique                                                 10
# top                                                     0
# freq                                                  150
#
# 0      COBRANÇA_VINDI_Qde Total de Faturas Inadimpletes  \
# count                                               252
# unique                                                7
# top                                                   0
# freq                                                218
#
# 0      COBRANÇA_VINDI_Valor Total Inadimplência  \
# count                                       252
# unique                                       16
# top                                           0
# freq                                        218
#
# 0      COBRANÇA_VINDI_Qde Perfis de Pagamento Inativos
# count                                             1202
# unique                                               1
# top                                              FALSE
# freq                                              1202
#
# [4 rows x 73 columns]

# %% [markdown]
# ## Managing missing values

# %%
import missingno as msno

# %%
msno.bar(data.iloc[:,:36])
# Out:
# <Axes: xlabel='0'>

# %%
msno.bar(data.iloc[:,36:])
# Out:
# <Axes: xlabel='0'>
